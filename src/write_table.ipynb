# %%
df = spark.read.table("samples.bakehouse.sales_customers")

df.write.mode("overwrite").saveAsTable("sales_customers_brz")

# %%
df1 = spark.read.table("samples.bakehouse.sales_suppliers")
df1.write.mode("overwrite").saveAsTable("sales_suppliers_brz")

# %%
df2 = spark.read.table("samples.bakehouse.sales_franchises")
df2.write.mode("overwrite").saveAsTable("sales_franchises_brz")

# %%
df3 = spark.read.table("samples.bakehouse.sales_transactions")
df3.write.mode("overwrite").saveAsTable("sales_transactions_brz")
